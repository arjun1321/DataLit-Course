# %% [markdown]
# # Twitter Webscraping for sentiment analysis

# %%
# !pip install pandas
# !pip install tweepy
# !pip install vaderSentiment
# Out:
# Requirement already satisfied: pandas in c:\users\arjun kumar\anaconda3\lib\site-packages (0.23.4)
# Requirement already satisfied: python-dateutil>=2.5.0 in c:\users\arjun kumar\anaconda3\lib\site-packages (from pandas) (2.7.5)
# Requirement already satisfied: pytz>=2011k in c:\users\arjun kumar\anaconda3\lib\site-packages (from pandas) (2018.7)
# Requirement already satisfied: numpy>=1.9.0 in c:\users\arjun kumar\anaconda3\lib\site-packages (from pandas) (1.15.4)
# Requirement already satisfied: six>=1.5 in c:\users\arjun kumar\anaconda3\lib\site-packages (from python-dateutil>=2.5.0->pandas) (1.12.0)
# Collecting tweepy
#   Downloading https://files.pythonhosted.org/packages/d5/5f/daac4b4e9b30d7d2a6fdd16a880ff79f27918fe388e4dfc1983dec3a9876/tweepy-3.7.0-py2.py3-none-any.whl
# Requirement already satisfied: PySocks>=1.5.7 in c:\users\arjun kumar\anaconda3\lib\site-packages (from tweepy) (1.6.8)
# Requirement already satisfied: requests>=2.11.1 in c:\users\arjun kumar\anaconda3\lib\site-packages (from tweepy) (2.21.0)
# Collecting requests-oauthlib>=0.7.0 (from tweepy)
#   Downloading https://files.pythonhosted.org/packages/c2/e2/9fd03d55ffb70fe51f587f20bcf407a6927eb121de86928b34d162f0b1ac/requests_oauthlib-1.2.0-py2.py3-none-any.whl
# Requirement already satisfied: six>=1.10.0 in c:\users\arjun kumar\anaconda3\lib\site-packages (from tweepy) (1.12.0)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\users\arjun kumar\anaconda3\lib\site-packages (from requests>=2.11.1->tweepy) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\arjun kumar\anaconda3\lib\site-packages (from requests>=2.11.1->tweepy) (2018.11.29)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in c:\users\arjun kumar\anaconda3\lib\site-packages (from requests>=2.11.1->tweepy) (1.24.1)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\arjun kumar\anaconda3\lib\site-packages (from requests>=2.11.1->tweepy) (3.0.4)
# Collecting oauthlib>=3.0.0 (from requests-oauthlib>=0.7.0->tweepy)
#   Downloading https://files.pythonhosted.org/packages/16/95/699466b05b72b94a41f662dc9edf87fda4289e3602ecd42d27fcaddf7b56/oauthlib-3.0.1-py2.py3-none-any.whl (142kB)
# Installing collected packages: oauthlib, requests-oauthlib, tweepy
# Successfully installed oauthlib-3.0.1 requests-oauthlib-1.2.0 tweepy-3.7.0
# Collecting vaderSentiment
#   Downloading https://files.pythonhosted.org/packages/86/9e/c53e1fc61aac5ee490a6ac5e21b1ac04e55a7c2aba647bb8411c9aadf24e/vaderSentiment-3.2.1-py2.py3-none-any.whl (125kB)
# Installing collected packages: vaderSentiment
# Successfully installed vaderSentiment-3.2.1

# %%
import tweepy
import pandas as pd
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# %%
# Twitter API Authentication variable

consumer_key = ''
consumer_secret = ''
access_token = ''
access_token_secret = ''

# %%
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)

api = tweepy.API(auth)

tweets = api.search('Artificial Intelligence', count=200)

data = pd.DataFrame(data = [tweet.text for tweet in tweets], columns=['Tweets'])

display(data.head(10))

print(tweets[0].created_at)
# Out:
#                                               Tweets
# 0  A crucial step for averting artificial intelli...
# 1  4 Ways Artificial Intelligence Will Drive Digi...
# 2  RT @Inteliot: .@Intel and @GEHealthcare are he...
# 3  How China became an Artificial Intelligence le...
# 4  RT @bdtechtalks: Artificial intelligence: frie...
# 5  Can artificial intelligence prevent the next P...
# 6  RT @thenextweb: AI will soon decide what we ea...
# 7  White House initiative will boost #ArtificialI...
# 8  RT @thenextweb: AI will soon decide what we ea...
# 9  Trump Signs Executive Order Promoting Artifici...
# 2019-02-13 18:02:21

# %%
# import natural language tool kit library

import nltk
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to C:\Users\Arjun
# [nltk_data]     Kumar\AppData\Roaming\nltk_data...
# True

# %%
sid = SentimentIntensityAnalyzer()

listy = []

for index, row in data.iterrows():
    ss = sid.polarity_scores(row["Tweets"])
    listy.append(ss)
    
    
se = pd.Series(listy)
data['Polarity'] = se.values

display(data.head(100))
# Out:
#                                                Tweets  \
# 0   A crucial step for averting artificial intelli...
# 1   4 Ways Artificial Intelligence Will Drive Digi...
# 2   RT @Inteliot: .@Intel and @GEHealthcare are he...
# 3   How China became an Artificial Intelligence le...
# 4   RT @bdtechtalks: Artificial intelligence: frie...
# 5   Can artificial intelligence prevent the next P...
# 6   RT @thenextweb: AI will soon decide what we ea...
# 7   White House initiative will boost #ArtificialI...
# 8   RT @thenextweb: AI will soon decide what we ea...
# 9   Trump Signs Executive Order Promoting Artifici...
# 10  A novel model developed by @MIT and @Microsoft...
# 11  RT @TheOnion: Artificial intelligence has been...
# 12  RT @johnpaulfarmer: Great to see Microsoft Pre...
# 13  RT @amywebb: Bay Area friends: Please join me ...
# 14  RT @EdamOrg: Today on EDAM Blog: "Why Turkey n...
# 15  Using Artificial Intelligence to Engineer Mate...
# 16  RT @daniel_kraft: The #AI will see you now... ...
# 17  US and China Lead the Artificial Intelligence ...
# 18  Artificial Intelligence Gaining Ground in Drug...
# 19  RT @ianbremmer: The US and China are in a “rac...
# 20  Trump Signs Executive Order Promoting Artifici...
# 21  Toddlers' learning is propelled by #curiosity!...
# 22  What is the difference between Cognitive Compu...
# 23  RT @predictionmonk: On Saturday, June 16, 2018...
# 24  Artificial intelligence takes on its biggest c...
# 25  Learning to Code for Artificial Intelligence\n...
# 26  President Donald Trump announced a new executi...
# 27  RT @into_AI: White House Touts Artificial Inte...
# 28  RT @uchi2chi1: Investing in #AI is crucial to ...
# 29  RT @david_blzqz: Trump lanza -finalmente- una ...
# ..                                                ...
# 70  RT @TheOnion: Artificial intelligence has been...
# 71  RT @kcassidy_kevin: @ClearBlade ranked a leadi...
# 72  UK to Invest £100 Million in Artificial Intell...
# 73  Pope discusses ethics of artificial intelligen...
# 74  RT @AmandaMsteph: At the Calgary Tower, where ...
# 75  From math to meaning: Artificial intelligence ...
# 76  Four questions to ask your analytics vendor, p...
# 77  Pope discusses ethics of artificial intelligen...
# 78  How Deep Learning Will Drive The Future of #Ma...
# 79  RT @PagliaAbp: This morning a meeting between ...
# 80  RT @MikeQuindazzi: 4 measures on the #AI race ...
# 81  RT @MicrosoftASIA: As one of the most vulnerab...
# 82  What the new #artificial #intelligence initiat...
# 83          RT @LovePoint199: https://t.co/QPYSM9V278
# 84         RT @NaturAmazingg: https://t.co/gnux3nYaOc
# 85  RT @McKinsey_MGI: Companies that fully absorb ...
# 86  RT @WaterlooEDC: Our #AI Cluster Map shows jus...
# 87  Pope discusses ethics of artificial intelligen...
# 88  Dignified work is integral to millions of Amer...
# 89  RT @hgetson: Artificial Intelligence is Powerf...
# 90  RT @McKinsey_MGI: Companies that fully absorb ...
# 91  .@AndrewYangVFA on job loss to artificial inte...
# 92  RT @bevakn: Big news are expected for $pat.v $...
# 93  Pope discusses ethics of artificial intelligen...
# 94  Pope discusses ethics of artificial intelligen...
# 95  An #AI system competed against a human debate ...
# 96  Pope discusses ethics of artificial intelligen...
# 97  Pope discusses ethics of artificial intelligen...
# 98  First topic on the @GestaltIT #Rundown is the ...
# 99  Great to see Microsoft President @BradSmi meet...
#
#                                              Polarity
# 0   {'neg': 0.263, 'neu': 0.511, 'pos': 0.226, 'co...
# 1   {'neg': 0.0, 'neu': 0.763, 'pos': 0.237, 'comp...
# 2   {'neg': 0.0, 'neu': 0.69, 'pos': 0.31, 'compou...
# 3   {'neg': 0.0, 'neu': 0.693, 'pos': 0.307, 'comp...
# 4   {'neg': 0.137, 'neu': 0.566, 'pos': 0.297, 'co...
# 5   {'neg': 0.0, 'neu': 0.625, 'pos': 0.375, 'comp...
# 6   {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 7   {'neg': 0.0, 'neu': 0.847, 'pos': 0.153, 'comp...
# 8   {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 9   {'neg': 0.0, 'neu': 0.517, 'pos': 0.483, 'comp...
# 10  {'neg': 0.0, 'neu': 0.619, 'pos': 0.381, 'comp...
# 11  {'neg': 0.0, 'neu': 0.759, 'pos': 0.241, 'comp...
# 12  {'neg': 0.0, 'neu': 0.773, 'pos': 0.227, 'comp...
# 13  {'neg': 0.0, 'neu': 0.621, 'pos': 0.379, 'comp...
# 14  {'neg': 0.0, 'neu': 0.866, 'pos': 0.134, 'comp...
# 15  {'neg': 0.0, 'neu': 0.721, 'pos': 0.279, 'comp...
# 16  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 17  {'neg': 0.0, 'neu': 0.688, 'pos': 0.312, 'comp...
# 18  {'neg': 0.0, 'neu': 0.543, 'pos': 0.457, 'comp...
# 19  {'neg': 0.0, 'neu': 0.906, 'pos': 0.094, 'comp...
# 20  {'neg': 0.0, 'neu': 0.556, 'pos': 0.444, 'comp...
# 21  {'neg': 0.0, 'neu': 0.79, 'pos': 0.21, 'compou...
# 22  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 23  {'neg': 0.0, 'neu': 0.86, 'pos': 0.14, 'compou...
# 24  {'neg': 0.0, 'neu': 0.672, 'pos': 0.328, 'comp...
# 25  {'neg': 0.0, 'neu': 0.846, 'pos': 0.154, 'comp...
# 26  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 27  {'neg': 0.052, 'neu': 0.802, 'pos': 0.146, 'co...
# 28  {'neg': 0.129, 'neu': 0.776, 'pos': 0.095, 'co...
# 29  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# ..                                                ...
# 70  {'neg': 0.0, 'neu': 0.759, 'pos': 0.241, 'comp...
# 71  {'neg': 0.0, 'neu': 0.819, 'pos': 0.181, 'comp...
# 72  {'neg': 0.0, 'neu': 0.718, 'pos': 0.282, 'comp...
# 73  {'neg': 0.0, 'neu': 0.744, 'pos': 0.256, 'comp...
# 74  {'neg': 0.0, 'neu': 0.754, 'pos': 0.246, 'comp...
# 75  {'neg': 0.0, 'neu': 0.763, 'pos': 0.237, 'comp...
# 76  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 77  {'neg': 0.0, 'neu': 0.744, 'pos': 0.256, 'comp...
# 78  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 79  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 80  {'neg': 0.0, 'neu': 0.745, 'pos': 0.255, 'comp...
# 81  {'neg': 0.186, 'neu': 0.641, 'pos': 0.173, 'co...
# 82  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 83  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 84  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 85  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 86  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 87  {'neg': 0.0, 'neu': 0.744, 'pos': 0.256, 'comp...
# 88  {'neg': 0.0, 'neu': 0.714, 'pos': 0.286, 'comp...
# 89  {'neg': 0.192, 'neu': 0.56, 'pos': 0.248, 'com...
# 90  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 91  {'neg': 0.202, 'neu': 0.526, 'pos': 0.272, 'co...
# 92  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 93  {'neg': 0.0, 'neu': 0.744, 'pos': 0.256, 'comp...
# 94  {'neg': 0.0, 'neu': 0.744, 'pos': 0.256, 'comp...
# 95  {'neg': 0.0, 'neu': 0.755, 'pos': 0.245, 'comp...
# 96  {'neg': 0.0, 'neu': 0.744, 'pos': 0.256, 'comp...
# 97  {'neg': 0.0, 'neu': 0.744, 'pos': 0.256, 'comp...
# 98  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 99  {'neg': 0.0, 'neu': 0.745, 'pos': 0.255, 'comp...
#
# [100 rows x 2 columns]
